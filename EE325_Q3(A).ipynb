# %% [markdown]
# <a href="https://colab.research.google.com/github/raushaniit2020/best-fitting-curve/blob/main/EE325_Q3(A).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

X, Y = [], []
for line in open('hw1c1.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

slope, intercept, r, p, std_err = stats.linregress(X, Y)

def myfunc(X):
   return  slope * X + intercept
  
mymodel = list(map(myfunc, X))

plt.scatter(X, Y)
plt.title("Height-Weight Analysis")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.plot(X, mymodel)
plt.show()
print("\nslope:" , slope)
print("\nintercept:", intercept)
# for example take any random height and check the corresponding approaximated  weight
weight = myfunc(158.13692470493567)
print(weight)
error = []
for i in range(100):
  E = abs(Y[i] - myfunc(X[i]))
  error.append(E)
incr_order = sorted(error)
print("\nincreasing order of error:" , incr_order)



plt.scatter(X, error)
plt.title("difference b/w true height y and intelligent guess ˆy using model")
plt.xlabel("Height")
plt.ylabel("Error")
plt.show()
# Out:
# slope: 0.5923424113347767
#
# intercept: -38.66420896827084
# 55.00699833251677
#
# increasing order of error: [0.04198420850850226, 0.07080195012395052, 0.08036154765844827, 0.08539836922511768, 0.09067334446960729, 0.1166710797523649, 0.12501153975252777, 0.15224254209989851, 0.15847361719941233, 0.173385208393654, 0.17378108117948443, 0.2508888554431081, 0.2698323770844695, 0.3518923843560984, 0.3674298015647608, 0.44609825432998207, 0.4496778146079592, 0.45220022064795273, 0.48929216533910846, 0.5213830094338263, 0.5458110039264241, 0.5557253784884466, 0.5717368677749022, 0.580664791808374, 0.6328791363617654, 0.6865745712288103, 0.7398437172147325, 0.7931071493431148, 0.8111915723100864, 0.8584030429553948, 0.9026392461839094, 0.9128123517723239, 0.9807783339196163, 1.0714739482439484, 1.1230010467027824, 1.1450361489900018, 1.1690473801072656, 1.1752895015227054, 1.176064021588246, 1.2542938559236987, 1.290967218808568, 1.2967146040337383, 1.3089131260333957, 1.3143340803827073, 1.3973665669020932, 1.4691720944296947, 1.4798105643486181, 1.4849625956503587, 1.4957094394127637, 1.6057958064541396, 1.6223715911563517, 1.6272357396167862, 1.6285988757526937, 1.656655206855966, 1.831983886078028, 1.8409909020893878, 1.8435888919061085, 1.8448008102857045, 1.8457607238391773, 1.8625428500947123, 1.9061066808900406, 1.9201653063647228, 1.9502842988624565, 2.0266268473594806, 2.209097155356986, 2.23990893159003, 2.256883211467816, 2.2642378692323106, 2.275507748246433, 2.323387080706567, 2.3304619812988747, 2.3965400300805655, 2.5841616710408033, 2.62987515069689, 2.6567267987186227, 2.67831620693363, 2.705939707304239, 2.7185238531989455, 2.749205874400623, 2.7640031848455067, 2.7799003653164007, 2.857174530970717, 2.9227298246022, 3.012355006054527, 3.058431370634125, 3.2330410849673896, 3.3848085898811178, 3.459279808225169, 3.5225639883576036, 3.5422261597576252, 3.7861176471461278, 4.468817631215899, 4.478433654344585, 4.591820825434553, 4.632747179796368, 4.984731731774389, 5.023980739599338, 5.100851972460347, 5.522780751058598, 7.171724413418687]
